# %%
from random_permutation import RandomPermutation
from matplotlib import pyplot as plt

# %% [markdown]
# The plot below shows that successive samples are utterly uncorrelated.

# %%
l = list(RandomPermutation(1000))
plt.scatter(l[1:], l[:-1], s=1)
plt.show()
